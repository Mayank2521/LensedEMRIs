# %% [markdown]
# # Lookup Table Generation for Point Lens Amplification factors
# ### For broader $y \in (10^{-3}, 10)$
# ### The settings are given here but whole lookup table is not generated. Instead, only part from $y \in (5, 10)$ is generated and then added to the existing data.

# %%
#!/home/anuj.mishra/anaconda3/envs/gwpy/bin/python

import numpy as np

import sys
import mpmath
from mpmath import hyp1f1
import math
import scipy
import pandas as pd

from copy import deepcopy

from itertools import product
from functools import partial
from tqdm import tqdm
import time
import matplotlib.pyplot as plt

sys.path.append('../src/')
# loading Python version of the point lens class
import pnt_lens_class 
pnt_lens_py = pnt_lens_class.point_lens()

# loading Cython version of the point lens class
import cythonized_pnt_lens_class as pnt_lens_cy

import pickle
import multiprocessing as mp
npool = 1  # int(sys.argv[1])


G = 6.67430*1e-11 
c = 299792458. 
M_sun = 1.989*1e30

# %% [markdown]
# ## 1. Bounds on w for lookup table

# %%
w_min, w_max = pnt_lens_cy.w_of_f(10, ml=1e-1), pnt_lens_cy.w_of_f(1024, ml=1e5)
('rough lower and upper limits of w:' , w_min, w_max )
# Out:
# ('rough lower and upper limits of w:',
#  0.00012382782869256283,
#  12679.969658118436)

# %% [markdown]
# ## 2. Required delta y

# %% [markdown]
# ### Checking in different y ranges:
# ### We will check the desired $\Delta y$ that works in each region then try to match different $\Delta y$ of each region with a single logspace array.

# %% [markdown]
# #### (vii) $y\in(5, 10)$

# %%
Mlzs = np.logspace(0, 5, 5)
ys = np.logspace(np.log10(5), np.log10(10), 10)

input_prms = np.array(list(product(Mlzs, ys)))
fs = np.arange(0.25, 1024, 1/4)
max_abs_err_abs_arr = np.array([None]*len(input_prms))
max_abs_err_phase_arr = np.array([None]*len(input_prms))
max_rel_err_abs_arr = np.array([None]*len(input_prms))
max_rel_err_phase_arr = np.array([None]*len(input_prms))

residuals = np.array([None]*len(input_prms))

delta_y=5e-7
i=0
for inp in tqdm(input_prms):
    Mlz, y = inp
    wfs_full = np.array([pnt_lens_cy.w_of_f(f, ml=Mlz, zl=0) for f in fs])
    wc = w_max #pnt_lens_cy.wc_geo_re1p0(y)
    
    wfs = wfs_full[wfs_full<wc]
    
    if len(wfs) == 0:
        residuals[i] = 1e-15
        max_abs_err_abs_arr[i] = 1e-15
        max_abs_err_phase_arr[i] = 1e-15
        max_rel_err_abs_arr[i] = 1e-15
        max_rel_err_phase_arr[i] = 1e-15
    else:    
        Ffs_cy = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])

        y=y+delta_y
        Ffs_cy_pert = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
        
        residuals[i] = np.linalg.norm(Ffs_cy/np.linalg.norm(Ffs_cy) - Ffs_cy_pert/np.linalg.norm(Ffs_cy_pert) )
        
        max_abs_err_abs = np.max(np.abs(np.abs(Ffs_cy) - np.abs(Ffs_cy_pert)))
        max_abs_err_phase = np.max(np.abs(np.angle(Ffs_cy) - np.angle(Ffs_cy_pert)))

        max_rel_err_abs = np.max(np.abs(np.abs(Ffs_cy) - np.abs(Ffs_cy_pert))/np.abs(Ffs_cy))
        max_rel_err_phase = np.max(np.abs((np.angle(Ffs_cy) - np.angle(Ffs_cy_pert))/np.angle(Ffs_cy)))

        max_abs_err_abs_arr[i] = max_abs_err_abs
        max_abs_err_phase_arr[i] = max_abs_err_phase
        max_rel_err_abs_arr[i] = max_rel_err_abs
        max_rel_err_phase_arr[i] = max_rel_err_phase
    i+=1   

 
data = np.dstack((residuals, max_abs_err_abs_arr, max_abs_err_phase_arr, max_rel_err_abs_arr, max_rel_err_phase_arr))[0]
df = pd.DataFrame(data, columns=['residuals', 'max_abs_err_abs', 'max_abs_err_phase', 'max_rel_err_abs', 'max_rel_err_phase'])
# df.to_csv('../data/error_analysis_y5p0-y10p0.dat', index=None, sep=' ')

# plotting residuals
plt.figure(figsize=(8, 5))
plt.hist(residuals, bins=np.logspace(np.log10(np.min(residuals)), np.log10(np.max(residuals))))
plt.xlabel('residual_norm')
plt.xscale('log')
plt.show()  

#plotting maximum absolute errors
fig, ax = plt.subplots(1, 2, figsize=(18,5.5))
plt.rcParams.update({'font.size':20})
ax[0].hist(max_abs_err_abs_arr, bins=np.logspace(np.log10(np.min(max_abs_err_abs_arr)), np.log10(np.max(max_abs_err_abs_arr)) ))
ax[1].hist(max_abs_err_phase_arr, bins=np.logspace(np.log10(np.min(max_abs_err_phase_arr)), np.log10(np.max(max_abs_err_phase_arr))) )
ax[0].set_xscale('log')
ax[1].set_xscale('log')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('max[abs(err)]')
plt.show()  

#plotting maximum relative errors
fig, ax = plt.subplots(1, 2, figsize=(18, 5.5))
plt.rcParams.update({'font.size':20})
ax[0].hist(max_rel_err_abs_arr, bins=np.logspace(np.log10(np.min(max_rel_err_abs_arr)), np.log10(np.max(max_rel_err_abs_arr))))
ax[1].hist(max_rel_err_phase_arr, bins=np.logspace(np.log10(np.min(max_rel_err_phase_arr)), np.log10(np.max(max_rel_err_phase_arr))))
ax[0].set_xscale('log')
ax[1].set_xscale('log')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('max[rel(err)]')
plt.show()

# plot of WFs where residual was maximum
fig, ax = plt.subplots(1, 2, figsize=(18, 5.5))
plt.rcParams.update({'font.size':20})
ind = np.argmax(residuals)
Mlz, y = input_prms[ind]
wfs_full = np.array([pnt_lens_cy.w_of_f(f, ml=Mlz, zl=0) for f in fs])
# wc = pnt_lens_cy.wc_geo_re1p0(y)
wfs = wfs_full[wfs_full<wc]
if len(wfs) == 0:
    wfs=wfs_full[:5]
Ffs_cy = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
y=y+delta_y
Ffs_cy_pert = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
fig.suptitle('plotting worst recovered template')
ax[0].plot(wfs, np.abs(Ffs_cy))
ax[0].plot(wfs, np.abs(Ffs_cy_pert))
ax[0].set_ylabel('abs[F(f)]')
ax[1].plot(wfs, np.angle(Ffs_cy))
ax[1].plot(wfs, np.angle(Ffs_cy_pert))
ax[1].set_ylabel('phase[F(f)]')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('w')
    tmp_ax.set_xscale('log')
plt.show()
# Out:
#  10%|███████████████▏                                                                                                                                        | 5/50 [00:00<00:05,  8.60it/s]IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
#  14%|█████████████████████▎                                                                                                                                  | 7/50 [00:00<00:04,  9.33it/s]IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
#  18%|███████████████████████████▎                                                                                                                            | 9/50 [00:01<00:03, 10.61it/s]
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.258747122872904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# ...
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0000005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
#  30%|█████████████████████████████████████████████▎                                                                                                         | 15/50 [00:02<00:04,  8.16it/s]IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# #### (i) $y\in(0.01,~0.05)$

# %%
Mlzs = np.logspace(0, 5, 5)
ys = np.logspace(-2, np.log10(0.05), 5)

input_prms = np.array(list(product(Mlzs, ys)))
fs = np.arange(0.25, 2048, 1/4)
max_abs_err_abs_arr = np.array([None]*len(input_prms))
max_abs_err_phase_arr = np.array([None]*len(input_prms))
max_rel_err_abs_arr = np.array([None]*len(input_prms))
max_rel_err_phase_arr = np.array([None]*len(input_prms))

residuals = np.array([None]*len(input_prms))

delta_y=3e-6
i=0
for inp in tqdm(input_prms):
    Mlz, y = inp
    wfs_full = np.array([pnt_lens_cy.w_of_f(f, ml=Mlz, zl=0) for f in fs])
    wc = pnt_lens_cy.wc_geo_re1p0(y)
    
    wfs = wfs_full[wfs_full<wc]
    
    if len(wfs) == 0:
        residuals[i] = 1e-15
        max_abs_err_abs_arr[i] = 1e-15
        max_abs_err_phase_arr[i] = 1e-15
        max_rel_err_abs_arr[i] = 1e-15
        max_rel_err_phase_arr[i] = 1e-15
    else:    
        Ffs_cy = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])

        y=y+delta_y
        Ffs_cy_pert = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
        
        residuals[i] = np.linalg.norm(Ffs_cy/np.linalg.norm(Ffs_cy) - Ffs_cy_pert/np.linalg.norm(Ffs_cy_pert) )
        
        max_abs_err_abs = np.max(np.abs(np.abs(Ffs_cy) - np.abs(Ffs_cy_pert)))
        max_abs_err_phase = np.max(np.abs(np.angle(Ffs_cy) - np.angle(Ffs_cy_pert)))

        max_rel_err_abs = np.max(np.abs(np.abs(Ffs_cy) - np.abs(Ffs_cy_pert))/np.abs(Ffs_cy))
        max_rel_err_phase = np.max(np.abs((np.angle(Ffs_cy) - np.angle(Ffs_cy_pert))/np.angle(Ffs_cy)))

        max_abs_err_abs_arr[i] = max_abs_err_abs
        max_abs_err_phase_arr[i] = max_abs_err_phase
        max_rel_err_abs_arr[i] = max_rel_err_abs
        max_rel_err_phase_arr[i] = max_rel_err_phase
    i+=1   

 
data = np.dstack((residuals, max_abs_err_abs_arr, max_abs_err_phase_arr, max_rel_err_abs_arr, max_rel_err_phase_arr))[0]
df = pd.DataFrame(data, columns=['residuals', 'max_abs_err_abs', 'max_abs_err_phase', 'max_rel_err_abs', 'max_rel_err_phase'])
df.to_csv('../data/error_analysis_y0p01-y0p05.dat', index=None, sep=' ')

# plotting residuals
plt.figure(figsize=(8, 5))
plt.hist(residuals, bins=np.logspace(np.log10(np.min(residuals)), np.log10(np.max(residuals))))
plt.xlabel('residual_norm')
plt.xscale('log')
plt.show()  

#plotting maximum absolute errors
fig, ax = plt.subplots(1, 2, figsize=(18,5.5))
plt.rcParams.update({'font.size':20})
ax[0].hist(max_abs_err_abs_arr, bins=np.logspace(np.log10(np.min(max_abs_err_abs_arr)), np.log10(np.max(max_abs_err_abs_arr)) ))
ax[1].hist(max_abs_err_phase_arr, bins=np.logspace(np.log10(np.min(max_abs_err_phase_arr)), np.log10(np.max(max_abs_err_phase_arr))) )
ax[0].set_xscale('log')
ax[1].set_xscale('log')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('max[abs(err)]')
plt.show()  

#plotting maximum relative errors
fig, ax = plt.subplots(1, 2, figsize=(18, 5.5))
plt.rcParams.update({'font.size':20})
ax[0].hist(max_rel_err_abs_arr, bins=np.logspace(np.log10(np.min(max_rel_err_abs_arr)), np.log10(np.max(max_rel_err_abs_arr))))
ax[1].hist(max_rel_err_phase_arr, bins=np.logspace(np.log10(np.min(max_rel_err_phase_arr)), np.log10(np.max(max_rel_err_phase_arr))))
ax[0].set_xscale('log')
ax[1].set_xscale('log')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('max[rel(err)]')
plt.show()

# plot of WFs where residual was maximum
fig, ax = plt.subplots(1, 2, figsize=(18, 5.5))
plt.rcParams.update({'font.size':20})
ind = np.argmax(residuals)
Mlz, y = input_prms[ind]
wfs_full = np.array([pnt_lens_cy.w_of_f(f, ml=Mlz, zl=0) for f in fs])
wc = pnt_lens_cy.wc_geo_re1p0(y)
wfs = wfs_full[wfs_full<wc]
if len(wfs) == 0:
    wfs=wfs_full[:5]
Ffs_cy = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
y=y+delta_y
Ffs_cy_pert = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
fig.suptitle('plotting worst recovered template')
ax[0].plot(wfs, np.abs(Ffs_cy))
ax[0].plot(wfs, np.abs(Ffs_cy_pert))
ax[0].set_ylabel('abs[F(f)]')
ax[1].plot(wfs, np.angle(Ffs_cy))
ax[1].plot(wfs, np.angle(Ffs_cy_pert))
ax[1].set_ylabel('phase[F(f)]')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('w')
    tmp_ax.set_xscale('log')
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:16<00:00,  1.48it/s]

# %% [markdown]
# #### (ii) $y\in(0.05,~0.08)$

# %%
Mlzs = np.logspace(0, 5, 5)
ys = np.logspace(np.log10(0.05), np.log10(0.08), 5)

input_prms = np.array(list(product(Mlzs, ys)))
fs = np.arange(0.25, 2048, 1/4)
max_abs_err_abs_arr = np.array([None]*len(input_prms))
max_abs_err_phase_arr = np.array([None]*len(input_prms))
max_rel_err_abs_arr = np.array([None]*len(input_prms))
max_rel_err_phase_arr = np.array([None]*len(input_prms))

residuals = np.array([None]*len(input_prms))

delta_y=1e-5
i=0
for inp in tqdm(input_prms):
    Mlz, y = inp
    wfs_full = np.array([pnt_lens_cy.w_of_f(f, ml=Mlz, zl=0) for f in fs])
    wc = pnt_lens_cy.wc_geo_re1p0(y)
    
    wfs = wfs_full[wfs_full<wc]
    
    if len(wfs) == 0:
        residuals[i] = 1e-15
        max_abs_err_abs_arr[i] = 1e-15
        max_abs_err_phase_arr[i] = 1e-15
        max_rel_err_abs_arr[i] = 1e-15
        max_rel_err_phase_arr[i] = 1e-15
    else:    
        Ffs_cy = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])

        y=y+delta_y
        Ffs_cy_pert = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
        
        residuals[i] = np.linalg.norm(Ffs_cy/np.linalg.norm(Ffs_cy) - Ffs_cy_pert/np.linalg.norm(Ffs_cy_pert) )
        
        max_abs_err_abs = np.max(np.abs(np.abs(Ffs_cy) - np.abs(Ffs_cy_pert)))
        max_abs_err_phase = np.max(np.abs(np.angle(Ffs_cy) - np.angle(Ffs_cy_pert)))

        max_rel_err_abs = np.max(np.abs(np.abs(Ffs_cy) - np.abs(Ffs_cy_pert))/np.abs(Ffs_cy))
        max_rel_err_phase = np.max(np.abs((np.angle(Ffs_cy) - np.angle(Ffs_cy_pert))/np.angle(Ffs_cy)))

        max_abs_err_abs_arr[i] = max_abs_err_abs
        max_abs_err_phase_arr[i] = max_abs_err_phase
        max_rel_err_abs_arr[i] = max_rel_err_abs
        max_rel_err_phase_arr[i] = max_rel_err_phase
    i+=1   

 
data = np.dstack((residuals, max_abs_err_abs_arr, max_abs_err_phase_arr, max_rel_err_abs_arr, max_rel_err_phase_arr))[0]
df = pd.DataFrame(data, columns=['residuals', 'max_abs_err_abs', 'max_abs_err_phase', 'max_rel_err_abs', 'max_rel_err_phase'])
df.to_csv('../data/error_analysis_y0p05-y0p08.dat', index=None, sep=' ')

# plotting residuals
plt.figure(figsize=(8, 5))
plt.hist(residuals, bins=np.logspace(np.log10(np.min(residuals)), np.log10(np.max(residuals))))
plt.xlabel('residual_norm')
plt.xscale('log')
plt.show()  

#plotting maximum absolute errors
fig, ax = plt.subplots(1, 2, figsize=(18,5.5))
plt.rcParams.update({'font.size':20})
ax[0].hist(max_abs_err_abs_arr, bins=np.logspace(np.log10(np.min(max_abs_err_abs_arr)), np.log10(np.max(max_abs_err_abs_arr)) ))
ax[1].hist(max_abs_err_phase_arr, bins=np.logspace(np.log10(np.min(max_abs_err_phase_arr)), np.log10(np.max(max_abs_err_phase_arr))) )
ax[0].set_xscale('log')
ax[1].set_xscale('log')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('max[abs(err)]')
plt.show()  

#plotting maximum relative errors
fig, ax = plt.subplots(1, 2, figsize=(18, 5.5))
plt.rcParams.update({'font.size':20})
ax[0].hist(max_rel_err_abs_arr, bins=np.logspace(np.log10(np.min(max_rel_err_abs_arr)), np.log10(np.max(max_rel_err_abs_arr))))
ax[1].hist(max_rel_err_phase_arr, bins=np.logspace(np.log10(np.min(max_rel_err_phase_arr)), np.log10(np.max(max_rel_err_phase_arr))))
ax[0].set_xscale('log')
ax[1].set_xscale('log')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('max[rel(err)]')
plt.show()

# plot of WFs where residual was maximum
fig, ax = plt.subplots(1, 2, figsize=(18, 5.5))
plt.rcParams.update({'font.size':20})
ind = np.argmax(residuals)
Mlz, y = input_prms[ind]
wfs_full = np.array([pnt_lens_cy.w_of_f(f, ml=Mlz, zl=0) for f in fs])
wc = pnt_lens_cy.wc_geo_re1p0(y)
wfs = wfs_full[wfs_full<wc]
if len(wfs) == 0:
    wfs=wfs_full[:5]
Ffs_cy = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
y=y+delta_y
Ffs_cy_pert = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
fig.suptitle('plotting worst recovered template')
ax[0].plot(wfs, np.abs(Ffs_cy))
ax[0].plot(wfs, np.abs(Ffs_cy_pert))
ax[0].set_ylabel('abs[F(f)]')
ax[1].plot(wfs, np.angle(Ffs_cy))
ax[1].plot(wfs, np.angle(Ffs_cy_pert))
ax[1].set_ylabel('phase[F(f)]')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('w')
    tmp_ax.set_xscale('log')
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:14<00:00,  1.68it/s]

# %%
ys_regs = [np.arange(1e-2, 1e-1, 1e-5), np.arange(1e-1, 1e-0, 5e-5), np.arange(1e0, 2e0, 1e-3),\
      np.arange(2e0, 5e0+1e-2, 1e-2)]
ys = np.concatenate(ys_regs)
ys2 = np.logspace(-2, np.log10(5), 35000)
len(ys), len(ys2)

dys = [ ys[i+1] - ys[i] for i in range(len(ys) -1 )]
dys2 = [ ys2[i+1] - ys2[i] for i in range(len(ys2) -1 )]

# plt.scatter(ys[:-1], dys)
# plt.scatter(ys2[:-1], dys2)
plt.scatter(dys, ys[:-1])
plt.scatter(dys2, ys2[:-1])
plt.yscale('log')
plt.xscale('log')

# %%
dys2[11000]
# Out:
# 1.2521853581623499e-05

# %%
# plt.scatter(ys[:-1], dys)
# plt.scatter(ys2[:-1], dys2)
plt.scatter(dys, ys[:-1])
plt.scatter(dys2, ys2[:-1])
plt.yscale('log')
plt.xscale('log')
plt.xlim(8e-6, 2e-5)
# Out:
# (8e-06, 2e-05)

# %% [markdown]
# #### (iii) $y\in(0.08,~0.10)$

# %%
Mlzs = np.logspace(0, 5, 5)
ys = np.logspace(np.log10(0.08), np.log10(0.10), 5)

input_prms = np.array(list(product(Mlzs, ys)))
fs = np.arange(0.25, 2048, 1/4)
max_abs_err_abs_arr = np.array([None]*len(input_prms))
max_abs_err_phase_arr = np.array([None]*len(input_prms))
max_rel_err_abs_arr = np.array([None]*len(input_prms))
max_rel_err_phase_arr = np.array([None]*len(input_prms))

residuals = np.array([None]*len(input_prms))

delta_y=1e-5
i=0
for inp in tqdm(input_prms):
    Mlz, y = inp
    wfs_full = np.array([pnt_lens_cy.w_of_f(f, ml=Mlz, zl=0) for f in fs])
    wc = pnt_lens_cy.wc_geo_re1p0(y)
    
    wfs = wfs_full[wfs_full<wc]
    
    if len(wfs) == 0:
        residuals[i] = 1e-15
        max_abs_err_abs_arr[i] = 1e-15
        max_abs_err_phase_arr[i] = 1e-15
        max_rel_err_abs_arr[i] = 1e-15
        max_rel_err_phase_arr[i] = 1e-15
    else:    
        Ffs_cy = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])

        y=y+delta_y
        Ffs_cy_pert = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
        
        residuals[i] = np.linalg.norm(Ffs_cy/np.linalg.norm(Ffs_cy) - Ffs_cy_pert/np.linalg.norm(Ffs_cy_pert) )
        
        max_abs_err_abs = np.max(np.abs(np.abs(Ffs_cy) - np.abs(Ffs_cy_pert)))
        max_abs_err_phase = np.max(np.abs(np.angle(Ffs_cy) - np.angle(Ffs_cy_pert)))

        max_rel_err_abs = np.max(np.abs(np.abs(Ffs_cy) - np.abs(Ffs_cy_pert))/np.abs(Ffs_cy))
        max_rel_err_phase = np.max(np.abs((np.angle(Ffs_cy) - np.angle(Ffs_cy_pert))/np.angle(Ffs_cy)))

        max_abs_err_abs_arr[i] = max_abs_err_abs
        max_abs_err_phase_arr[i] = max_abs_err_phase
        max_rel_err_abs_arr[i] = max_rel_err_abs
        max_rel_err_phase_arr[i] = max_rel_err_phase
    i+=1   

 
data = np.dstack((residuals, max_abs_err_abs_arr, max_abs_err_phase_arr, max_rel_err_abs_arr, max_rel_err_phase_arr))[0]
df = pd.DataFrame(data, columns=['residuals', 'max_abs_err_abs', 'max_abs_err_phase', 'max_rel_err_abs', 'max_rel_err_phase'])
df.to_csv('../data/error_analysis_y0p05-y0p08.dat', index=None, sep=' ')

# plotting residuals
plt.figure(figsize=(8, 5))
plt.hist(residuals, bins=np.logspace(np.log10(np.min(residuals)), np.log10(np.max(residuals))))
plt.xlabel('residual_norm')
plt.xscale('log')
plt.show()  

#plotting maximum absolute errors
fig, ax = plt.subplots(1, 2, figsize=(18,5.5))
plt.rcParams.update({'font.size':20})
ax[0].hist(max_abs_err_abs_arr, bins=np.logspace(np.log10(np.min(max_abs_err_abs_arr)), np.log10(np.max(max_abs_err_abs_arr)) ))
ax[1].hist(max_abs_err_phase_arr, bins=np.logspace(np.log10(np.min(max_abs_err_phase_arr)), np.log10(np.max(max_abs_err_phase_arr))) )
ax[0].set_xscale('log')
ax[1].set_xscale('log')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('max[abs(err)]')
plt.show()  

#plotting maximum relative errors
fig, ax = plt.subplots(1, 2, figsize=(18, 5.5))
plt.rcParams.update({'font.size':20})
ax[0].hist(max_rel_err_abs_arr, bins=np.logspace(np.log10(np.min(max_rel_err_abs_arr)), np.log10(np.max(max_rel_err_abs_arr))))
ax[1].hist(max_rel_err_phase_arr, bins=np.logspace(np.log10(np.min(max_rel_err_phase_arr)), np.log10(np.max(max_rel_err_phase_arr))))
ax[0].set_xscale('log')
ax[1].set_xscale('log')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('max[rel(err)]')
plt.show()

# plot of WFs where residual was maximum
fig, ax = plt.subplots(1, 2, figsize=(18, 5.5))
plt.rcParams.update({'font.size':20})
ind = np.argmax(residuals)
Mlz, y = input_prms[ind]
wfs_full = np.array([pnt_lens_cy.w_of_f(f, ml=Mlz, zl=0) for f in fs])
wc = pnt_lens_cy.wc_geo_re1p0(y)
wfs = wfs_full[wfs_full<wc]
if len(wfs) == 0:
    wfs=wfs_full[:5]
Ffs_cy = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
y=y+delta_y
Ffs_cy_pert = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
fig.suptitle('plotting worst recovered template')
ax[0].plot(wfs, np.abs(Ffs_cy))
ax[0].plot(wfs, np.abs(Ffs_cy_pert))
ax[0].set_ylabel('abs[F(f)]')
ax[1].plot(wfs, np.angle(Ffs_cy))
ax[1].plot(wfs, np.angle(Ffs_cy_pert))
ax[1].set_ylabel('phase[F(f)]')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('w')
    tmp_ax.set_xscale('log')
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:14<00:00,  1.69it/s]

# %% [markdown]
# #### (iv) $y\in(0.1,~0.5)$

# %%
ys_regs = [np.arange(1e-2, 1e-1, 1e-5), np.arange(1e-1, 1e-0, 5e-5), np.arange(1e0, 2e0, 1e-3),\
      np.arange(2e0, 5e0+1e-2, 1e-2)]
ys = np.concatenate(ys_regs)
ys2 = np.logspace(-2, np.log10(5), 35000)
len(ys), len(ys2)

dys = [ ys[i+1] - ys[i] for i in range(len(ys) -1 )]
dys2 = [ ys2[i+1] - ys2[i] for i in range(len(ys2) -1 )]

# plt.scatter(ys[:-1], dys)
# plt.scatter(ys2[:-1], dys2)
plt.scatter(dys, ys[:-1])
plt.scatter(dys2, ys2[:-1])
plt.yscale('log')
plt.xscale('log')

# %%
Mlzs = np.logspace(0, 5, 5)
ys = np.logspace(-1, 0.5, 5)

input_prms = np.array(list(product(Mlzs, ys)))
fs = np.arange(0.25, 2048, 1/4)
max_abs_err_abs_arr = np.array([None]*len(input_prms))
max_abs_err_phase_arr = np.array([None]*len(input_prms))
max_rel_err_abs_arr = np.array([None]*len(input_prms))
max_rel_err_phase_arr = np.array([None]*len(input_prms))

residuals = np.array([None]*len(input_prms))

delta_y=5e-5
i=0
for inp in tqdm(input_prms):
    Mlz, y = inp
    wfs_full = np.array([pnt_lens_cy.w_of_f(f, ml=Mlz, zl=0) for f in fs])
    wc = pnt_lens_cy.wc_geo_re1p0(y)
    
    wfs = wfs_full[wfs_full<wc]
    
    if len(wfs) == 0:
        residuals[i] = 1e-15
        max_abs_err_abs_arr[i] = 1e-15
        max_abs_err_phase_arr[i] = 1e-15
        max_rel_err_abs_arr[i] = 1e-15
        max_rel_err_phase_arr[i] = 1e-15
    else:    
        Ffs_cy = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])

        y=y+delta_y
        Ffs_cy_pert = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
        
        residuals[i] = np.linalg.norm(Ffs_cy/np.linalg.norm(Ffs_cy) - Ffs_cy_pert/np.linalg.norm(Ffs_cy_pert) )
        
        max_abs_err_abs = np.max(np.abs(np.abs(Ffs_cy) - np.abs(Ffs_cy_pert)))
        max_abs_err_phase = np.max(np.abs(np.angle(Ffs_cy) - np.angle(Ffs_cy_pert)))

        max_rel_err_abs = np.max(np.abs(np.abs(Ffs_cy) - np.abs(Ffs_cy_pert))/np.abs(Ffs_cy))
        max_rel_err_phase = np.max(np.abs((np.angle(Ffs_cy) - np.angle(Ffs_cy_pert))/np.angle(Ffs_cy)))

        max_abs_err_abs_arr[i] = max_abs_err_abs
        max_abs_err_phase_arr[i] = max_abs_err_phase
        max_rel_err_abs_arr[i] = max_rel_err_abs
        max_rel_err_phase_arr[i] = max_rel_err_phase
    i+=1   

 
data = np.dstack((residuals, max_abs_err_abs_arr, max_abs_err_phase_arr, max_rel_err_abs_arr, max_rel_err_phase_arr))[0]
df = pd.DataFrame(data, columns=['residuals', 'max_abs_err_abs', 'max_abs_err_phase', 'max_rel_err_abs', 'max_rel_err_phase'])
df.to_csv('../data/error_analysis_y0p1-y1p0.dat', index=None, sep=' ')

# plotting residuals
plt.figure(figsize=(8, 5))
plt.hist(residuals, bins=np.logspace(np.log10(np.min(residuals)), np.log10(np.max(residuals))))
plt.xlabel('residual_norm')
plt.xscale('log')
plt.show()  

#plotting maximum absolute errors
fig, ax = plt.subplots(1, 2, figsize=(18,5.5))
plt.rcParams.update({'font.size':20})
ax[0].hist(max_abs_err_abs_arr, bins=np.logspace(np.log10(np.min(max_abs_err_abs_arr)), np.log10(np.max(max_abs_err_abs_arr)) ))
ax[1].hist(max_abs_err_phase_arr, bins=np.logspace(np.log10(np.min(max_abs_err_phase_arr)), np.log10(np.max(max_abs_err_phase_arr))) )
ax[0].set_xscale('log')
ax[1].set_xscale('log')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('max[abs(err)]')
plt.show()  

#plotting maximum relative errors
fig, ax = plt.subplots(1, 2, figsize=(18, 5.5))
plt.rcParams.update({'font.size':20})
ax[0].hist(max_rel_err_abs_arr, bins=np.logspace(np.log10(np.min(max_rel_err_abs_arr)), np.log10(np.max(max_rel_err_abs_arr))))
ax[1].hist(max_rel_err_phase_arr, bins=np.logspace(np.log10(np.min(max_rel_err_phase_arr)), np.log10(np.max(max_rel_err_phase_arr))))
ax[0].set_xscale('log')
ax[1].set_xscale('log')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('max[rel(err)]')
plt.show()

# plot of WFs where residual was maximum
fig, ax = plt.subplots(1, 2, figsize=(18, 5.5))
plt.rcParams.update({'font.size':20})
ind = np.argmax(residuals)
Mlz, y = input_prms[ind]
wfs_full = np.array([pnt_lens_cy.w_of_f(f, ml=Mlz, zl=0) for f in fs])
wc = pnt_lens_cy.wc_geo_re1p0(y)
wfs = wfs_full[wfs_full<wc]
if len(wfs) == 0:
    wfs=wfs_full[:5]
Ffs_cy = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
y=y+delta_y
Ffs_cy_pert = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
fig.suptitle('plotting worst recovered template')
ax[0].plot(wfs, np.abs(Ffs_cy))
ax[0].plot(wfs, np.abs(Ffs_cy_pert))
ax[0].set_ylabel('abs[F(f)]')
ax[1].plot(wfs, np.angle(Ffs_cy))
ax[1].plot(wfs, np.angle(Ffs_cy_pert))
ax[1].set_ylabel('phase[F(f)]')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('w')
    tmp_ax.set_xscale('log')
plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:50<00:00,  1.98it/s]

# %% [markdown]
# #### (v) $y\in(1.0,~2.0)$

# %%
Mlzs = np.logspace(0, 5, 10)
ys = np.logspace(0, np.log10(2-1e-2), 10)

input_prms = np.array(list(product(Mlzs, ys)))
fs = np.arange(0.25, 2048, 1/4)
max_abs_err_abs_arr = np.array([None]*len(input_prms))
max_abs_err_phase_arr = np.array([None]*len(input_prms))
max_rel_err_abs_arr = np.array([None]*len(input_prms))
max_rel_err_phase_arr = np.array([None]*len(input_prms))

residuals = np.array([None]*len(input_prms))

delta_y=5e-3
i=0
for inp in tqdm(input_prms):
    Mlz, y = inp
    wfs_full = np.array([pnt_lens_cy.w_of_f(f, ml=Mlz, zl=0) for f in fs])
    wc = pnt_lens_cy.wc_geo_re1p0(y)
    
    wfs = wfs_full[wfs_full<wc]
    
    if len(wfs) == 0:
        residuals[i] = 1e-15
        max_abs_err_abs_arr[i] = 1e-15
        max_abs_err_phase_arr[i] = 1e-15
        max_rel_err_abs_arr[i] = 1e-15
        max_rel_err_phase_arr[i] = 1e-15
    else:    
        Ffs_cy = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])

        y=y+delta_y
        Ffs_cy_pert = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
        
        residuals[i] = np.linalg.norm(Ffs_cy/np.linalg.norm(Ffs_cy) - Ffs_cy_pert/np.linalg.norm(Ffs_cy_pert) )
        
        max_abs_err_abs = np.max(np.abs(np.abs(Ffs_cy) - np.abs(Ffs_cy_pert)))
        max_abs_err_phase = np.max(np.abs(np.angle(Ffs_cy) - np.angle(Ffs_cy_pert)))

        max_rel_err_abs = np.max(np.abs(np.abs(Ffs_cy) - np.abs(Ffs_cy_pert))/np.abs(Ffs_cy))
        max_rel_err_phase = np.max(np.abs((np.angle(Ffs_cy) - np.angle(Ffs_cy_pert))/np.angle(Ffs_cy)))

        max_abs_err_abs_arr[i] = max_abs_err_abs
        max_abs_err_phase_arr[i] = max_abs_err_phase
        max_rel_err_abs_arr[i] = max_rel_err_abs
        max_rel_err_phase_arr[i] = max_rel_err_phase
    i+=1   

 
data = np.dstack((residuals, max_abs_err_abs_arr, max_abs_err_phase_arr, max_rel_err_abs_arr, max_rel_err_phase_arr))[0]
df = pd.DataFrame(data, columns=['residuals', 'max_abs_err_abs', 'max_abs_err_phase', 'max_rel_err_abs', 'max_rel_err_phase'])
df.to_csv('../data/error_analysis_y1p0-y2p0.dat', index=None, sep=' ')

# plotting residuals
plt.figure(figsize=(8, 5))
plt.hist(residuals, bins=np.logspace(np.log10(np.min(residuals)), np.log10(np.max(residuals))))
plt.xlabel('residual_norm')
plt.xscale('log')
plt.show()  

#plotting maximum absolute errors
fig, ax = plt.subplots(1, 2, figsize=(18,5.5))
plt.rcParams.update({'font.size':20})
ax[0].hist(max_abs_err_abs_arr, bins=np.logspace(np.log10(np.min(max_abs_err_abs_arr)), np.log10(np.max(max_abs_err_abs_arr)) ))
ax[1].hist(max_abs_err_phase_arr, bins=np.logspace(np.log10(np.min(max_abs_err_phase_arr)), np.log10(np.max(max_abs_err_phase_arr))) )
ax[0].set_xscale('log')
ax[1].set_xscale('log')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('max[abs(err)]')
plt.show()  

#plotting maximum relative errors
fig, ax = plt.subplots(1, 2, figsize=(18, 5.5))
plt.rcParams.update({'font.size':20})
ax[0].hist(max_rel_err_abs_arr, bins=np.logspace(np.log10(np.min(max_rel_err_abs_arr)), np.log10(np.max(max_rel_err_abs_arr))))
ax[1].hist(max_rel_err_phase_arr, bins=np.logspace(np.log10(np.min(max_rel_err_phase_arr)), np.log10(np.max(max_rel_err_phase_arr))))
ax[0].set_xscale('log')
ax[1].set_xscale('log')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('max[rel(err)]')
plt.show()

# plot of WFs where residual was maximum
fig, ax = plt.subplots(1, 2, figsize=(18, 5.5))
plt.rcParams.update({'font.size':20})
ind = np.argmax(residuals)
Mlz, y = input_prms[ind]
wfs_full = np.array([pnt_lens_cy.w_of_f(f, ml=Mlz, zl=0) for f in fs])
wc = pnt_lens_cy.wc_geo_re1p0(y)
wfs = wfs_full[wfs_full<wc]
if len(wfs) == 0:
    wfs=wfs_full[:5]
Ffs_cy = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
y=y+delta_y
Ffs_cy_pert = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
fig.suptitle('plotting worst recovered template')
ax[0].plot(wfs, np.abs(Ffs_cy))
ax[0].plot(wfs, np.abs(Ffs_cy_pert))
ax[0].set_ylabel('abs[F(f)]')
ax[1].plot(wfs, np.angle(Ffs_cy))
ax[1].plot(wfs, np.angle(Ffs_cy_pert))
ax[1].set_ylabel('phase[F(f)]')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('w')
    tmp_ax.set_xscale('log')
plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:37<00:00,  2.64it/s]

# %% [markdown]
# #### (vi) $y\in(2.0,~5.0)$

# %%
Mlzs = np.logspace(0, 5, 10)
ys = np.logspace(np.log10(2), np.log10(5-1e-1), 10)

input_prms = np.array(list(product(Mlzs, ys)))
fs = np.arange(0.25, 2048, 1/4)
max_abs_err_abs_arr = np.array([None]*len(input_prms))
max_abs_err_phase_arr = np.array([None]*len(input_prms))
max_rel_err_abs_arr = np.array([None]*len(input_prms))
max_rel_err_phase_arr = np.array([None]*len(input_prms))

residuals = np.array([None]*len(input_prms))

delta_y=1e-2
i=0
for inp in tqdm(input_prms):
    Mlz, y = inp
    wfs_full = np.array([pnt_lens_cy.w_of_f(f, ml=Mlz, zl=0) for f in fs])
    wc = pnt_lens_cy.wc_geo_re1p0(y)
    
    wfs = wfs_full[wfs_full<wc]
    
    if len(wfs) == 0:
        residuals[i] = 1e-15
        max_abs_err_abs_arr[i] = 1e-15
        max_abs_err_phase_arr[i] = 1e-15
        max_rel_err_abs_arr[i] = 1e-15
        max_rel_err_phase_arr[i] = 1e-15
    else:    
        Ffs_cy = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])

        y=y+delta_y
        Ffs_cy_pert = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
        
        residuals[i] = np.linalg.norm(Ffs_cy/np.linalg.norm(Ffs_cy) - Ffs_cy_pert/np.linalg.norm(Ffs_cy_pert) )
        
        max_abs_err_abs = np.max(np.abs(np.abs(Ffs_cy) - np.abs(Ffs_cy_pert)))
        max_abs_err_phase = np.max(np.abs(np.angle(Ffs_cy) - np.angle(Ffs_cy_pert)))

        max_rel_err_abs = np.max(np.abs(np.abs(Ffs_cy) - np.abs(Ffs_cy_pert))/np.abs(Ffs_cy))
        max_rel_err_phase = np.max(np.abs((np.angle(Ffs_cy) - np.angle(Ffs_cy_pert))/np.angle(Ffs_cy)))

        max_abs_err_abs_arr[i] = max_abs_err_abs
        max_abs_err_phase_arr[i] = max_abs_err_phase
        max_rel_err_abs_arr[i] = max_rel_err_abs
        max_rel_err_phase_arr[i] = max_rel_err_phase
    i+=1   

 
data = np.dstack((residuals, max_abs_err_abs_arr, max_abs_err_phase_arr, max_rel_err_abs_arr, max_rel_err_phase_arr))[0]
df = pd.DataFrame(data, columns=['residuals', 'max_abs_err_abs', 'max_abs_err_phase', 'max_rel_err_abs', 'max_rel_err_phase'])
df.to_csv('../data/error_analysis_y2p0-y5p0.dat', index=None, sep=' ')

# plotting residuals
plt.figure(figsize=(8, 5))
plt.hist(residuals, bins=np.logspace(np.log10(np.min(residuals)), np.log10(np.max(residuals))))
plt.xlabel('residual_norm')
plt.xscale('log')
plt.show()  

#plotting maximum absolute errors
fig, ax = plt.subplots(1, 2, figsize=(18,5.5))
plt.rcParams.update({'font.size':20})
ax[0].hist(max_abs_err_abs_arr, bins=np.logspace(np.log10(np.min(max_abs_err_abs_arr)), np.log10(np.max(max_abs_err_abs_arr)) ))
ax[1].hist(max_abs_err_phase_arr, bins=np.logspace(np.log10(np.min(max_abs_err_phase_arr)), np.log10(np.max(max_abs_err_phase_arr))) )
ax[0].set_xscale('log')
ax[1].set_xscale('log')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('max[abs(err)]')
plt.show()  

#plotting maximum relative errors
fig, ax = plt.subplots(1, 2, figsize=(18, 5.5))
plt.rcParams.update({'font.size':20})
ax[0].hist(max_rel_err_abs_arr, bins=np.logspace(np.log10(np.min(max_rel_err_abs_arr)), np.log10(np.max(max_rel_err_abs_arr))))
ax[1].hist(max_rel_err_phase_arr, bins=np.logspace(np.log10(np.min(max_rel_err_phase_arr)), np.log10(np.max(max_rel_err_phase_arr))))
ax[0].set_xscale('log')
ax[1].set_xscale('log')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('max[rel(err)]')
plt.show()

# plot of WFs where residual was maximum
fig, ax = plt.subplots(1, 2, figsize=(18, 5.5))
plt.rcParams.update({'font.size':20})
ind = np.argmax(residuals)
Mlz, y = input_prms[ind]
wfs_full = np.array([pnt_lens_cy.w_of_f(f, ml=Mlz, zl=0) for f in fs])
wc = pnt_lens_cy.wc_geo_re1p0(y)
wfs = wfs_full[wfs_full<wc]
if len(wfs) == 0:
    wfs=wfs_full[:5]
Ffs_cy = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
y=y+delta_y
Ffs_cy_pert = np.array([pnt_lens_cy.point_Fw_eff(wf, y=y) for wf in wfs])
fig.suptitle('plotting worst recovered template')
ax[0].plot(wfs, np.abs(Ffs_cy))
ax[0].plot(wfs, np.abs(Ffs_cy_pert))
ax[0].set_ylabel('abs[F(f)]')
ax[1].plot(wfs, np.angle(Ffs_cy))
ax[1].plot(wfs, np.angle(Ffs_cy_pert))
ax[1].set_ylabel('phase[F(f)]')
for tmp_ax in ax.flatten():
    tmp_ax.set_xlabel('w')
    tmp_ax.set_xscale('log')
plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:33<00:00,  2.97it/s]

# %% [markdown]
# ## 3. Grid Generation

# %%
## fitting a logspace for y grid points 
ys_regs = [np.arange(1e-3, 1e-2, 5e-7), np.arange(1e-2, 1e-1, 1e-5), np.arange(1e-1, 1e-0, 5e-5), np.arange(1e0, 2e0, 1e-3),\
      np.arange(2e0, 5e0+1e-2, 1e-2), np.arange(5e0+5e-2, 10e0+1e-2, 5e-2)]
ys = np.concatenate(ys_regs)
ys2 = np.logspace(-3, np.log10(10), 50000)
print(len(ys), len(ys2))

dys = [ ys[i+1] - ys[i] for i in range(len(ys) -1 )]
dys2 = [ ys2[i+1] - ys2[i] for i in range(len(ys2) -1 )]

# plt.scatter(ys[:-1], dys)
# plt.scatter(ys2[:-1], dys2)
fig, ax = plt.subplots(figsize=(10, 6))
plt.scatter(dys, ys[:-1])
plt.scatter(dys2, ys2[:-1])
plt.yscale('log')
plt.xscale('log')
plt.xlabel('$\Delta y$')
plt.ylabel('y')
plt.xticks(np.logspace(-7, -2, 5))
# plt.xlim(1e-8, 3e-2)
plt.show()
# Out:
# 46402 50000

# %%
## fitting a logspace for y grid points 

ys1 = np.logspace(-2, np.log10(5), 40000)
ys2 = np.logspace(-3, -2, 15000)
ys3 = np.logspace(np.log10(5), 1, 4500)
print(len(ys), len(ys2))

dys1 = [ ys1[i+1] - ys1[i] for i in range(len(ys1) -1 )]
dys2 = [ ys2[i+1] - ys2[i] for i in range(len(ys2) -1 )]
dys3 = [ ys3[i+1] - ys3[i] for i in range(len(ys3) -1 )]

# plt.scatter(ys[:-1], dys)
# plt.scatter(ys2[:-1], dys2)

fig, ax = plt.subplots(figsize=(10, 6))
plt.scatter(dys1, ys1[:-1])
plt.scatter(dys2, ys2[:-1])
plt.scatter(dys3, ys3[:-1])
plt.yscale('log')
plt.xscale('log')
plt.xlabel('$\Delta y$')
plt.ylabel('y')
plt.xticks(np.logspace(-7, -2, 5))
# plt.xlim(1e-8, 3e-2)
plt.show()
# Out:
# 46402 15000

# %%
## fitting a logspace for y grid points 

ys1 = np.logspace(-2, np.log10(5), 40000)
ys2 = np.logspace(-3, -2, 15000)
ys3 = np.logspace(np.log10(5), 1, 4500)
ys_c = np.concatenate((ys1, ys2, ys3))
dys_c = [ ys_c[i+1] - ys_c[i] for i in range(len(ys_c) -1 )]

ys_c2 = np.logspace(-3, np.log10(10), 60000)
dys_c2 = [ ys_c2[i+1] - ys_c2[i] for i in range(len(ys_c2) -1 )]


fig, ax = plt.subplots(figsize=(10, 6))
plt.scatter(dys_c, ys_c[:-1])
plt.scatter(dys_c2, ys_c2[:-1], s=1)
plt.yscale('log')
plt.xscale('log')
plt.xlabel('$\Delta y$')
plt.ylabel('y')
plt.xticks(np.logspace(-7, -2, 5))
# plt.ylim(1e-2, 1e-0)
# plt.xlim(1e-6, 1e-4)
plt.show()

# %%
## fitting a logspace for w grid points 

ws_regs = [np.arange(1e-4, 1e-3, 1e-6),
np.arange(1e-3, 1e-2, 1e-5),
np.arange(1e-2, 1e-1, 1e-4),
np.arange(1e-1, 1e-0, 1e-3),
np.arange(1e-0, 1e1, 1e-2),
np.arange(1e1, 1e2, 1e-1),
np.arange(1e2, 1e3, 1e0),
np.arange(1e3, 1.3e4+1e1, 1e1)]
ws = np.concatenate(ws_regs)

ws2 = np.logspace(-4, np.log10(1.3e4), 8000)

print(len(ws), len(ws2))

dws = [ ws[i+1] - ws[i] for i in range(len(ws) -1 )]
dws2 = [ ws2[i+1] - ws2[i] for i in range(len(ws2) -1 )]

# plt.scatter(ys[:-1], dys)
# plt.scatter(ys2[:-1], dys2)
plt.scatter(dws, ws[:-1])
plt.scatter(dws2, ws2[:-1])
plt.yscale('log')
plt.xscale('log')
plt.xlabel('$\Delta w$')
plt.ylabel('w')
plt.xlim(1e-7, 1e2)
plt.show()
# Out:
# 7502 8000

# %%
### Grid Generation ###

ws_min, ws_max = 1e-4, 1.3e4

ys = np.logspace(-3, 1, 60000)
ws = np.logspace(np.log10(ws_min), np.log10(ws_max), 8000)

y_w_grid = []   #np.array([None]*len(input_prms))
for y in ys[:]:
    if y>0.01:
        wc = pnt_lens_cy.wc_geo_re1p0(y)
    else:
        wc = ws_max
    tmp_ws = ws[ws<=1.1*wc]
    y_w_grid.append([y, tmp_ws])
    
y_w_grid = np.array(y_w_grid, dtype=object)     
grid_num =  np.sum([len(y_w_grid[i][1]) for i in range(len(y_w_grid))])

print('ys: ({:.3f}, {:.3f}), len(ys)={}'.format(ys[0], ys[-1], len(ys)))
print('ws: ({:.4f}, {:2f}), max_len(ws)={}'.format(ws[0], ws[-1], len(ws)))
print('Total points in grid: ', grid_num)
# Out:
# Warning: y = 5.001055232864312 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.001822994935315 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.002590874873167 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.003358872695954 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.004126988421782 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.004895222068742 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.005663573654949 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.006432043198496 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.007200630717503 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.007969336230073 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.008738159754329 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.009507101308379 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.010276160910351 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.01104533857836 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.011814634330541 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.012584048185011 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0133535801599125 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.014123230273369 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.014892998543527 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.015662884988515 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.016432889626487 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.017203012475576 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.017973253553942 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.018743612879724 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.019514090471085 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.020284686346177 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.021055400523155 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.021826233020189 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.022597183855433 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0233682530470665 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.024139440613248 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.024910746572161 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.02568217094197 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.026453713740865 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.027225374987016 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0279971546986175 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.028769052893847 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.029541069590903 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.030313204807968 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.031085458563249 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.031857830874932 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.032630321761228 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.033402931240331 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.034175659330457 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.034948506049806 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0357214714166 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.036494555449042 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.037267758165361 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.038041079583767 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.038814519722494 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.039588078599756 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.040361756233794 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.041135552642828 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.041909467845103 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.042683501858845 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.043457654702307 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.044231926393717 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.045006316951335 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.045780826393397 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.046555454738165 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.047330202003882 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.048105068208815 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.048880053371215 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.049655157509353 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.050430380641483 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.051205722785886 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.05198118396082 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.05275676418457 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.053532463475403 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.054308281851607 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.055084219331453 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.055860275933238 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.056636451675238 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.057412746575754 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.058189160653075 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.058965693925491 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.059742346411311 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.060519118128827 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0612960090963535 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.062073019332186 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.062850148854648 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.063627397682039 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.064404765832687 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.065182253324899 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.065959860177007 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.066737586407325 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.06751543203419 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.068293397075922 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.069071481550863 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.069849685477339 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.070628008873699 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.071406451758271 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0721850141494125 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.072963696065457 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.073742497524767 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.074521418545682 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.075300459146569 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.076079619345775 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.076858899161671 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.07763829861261 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.078417817716969 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.079197456493107 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.079977214959406 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.080757093134232 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.081537091035971 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.082317208682993 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.083097446093694 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.083877803286447 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.084658280279654 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.085438877091693 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.086219593740973 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.087000430245878 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.08778138662482 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.08856246289619 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.089343659078407 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.090124975189868 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.090906411248994 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.09168796727419 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.092469643283883 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.093251439296484 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.094033355330425 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.094815391404121 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.095597547536012 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.096379823744523 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.097162220048084 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.097944736465142 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.098727373014126 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.099510129713489 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.100293006581667 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.101076003637119 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.101859120898284 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.102642358383628 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.103425716111596 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.104209194100659 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.104992792369269 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.105776510935902 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1065603498190155 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1073443090370905 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.10812838860859 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.108912588552003 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.109696908885796 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.110481349628464 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.111265910798481 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.112050592414344 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.112835394494536 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.113620317057559 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.114405360121901 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.11519052370607 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.115975807828558 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.116761212507882 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.117546737762537 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.118332383611047 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1191181500719125 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.119904037163662 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.120690044904804 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.121476173313871 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.122262422409378 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.123048792209861 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.123835282733843 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1246218939998665 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1254086260264575 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.126195478832166 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.126982452435524 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.127769546855085 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.128556762109387 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1293440982169916 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.130131555196442 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.130919133066304 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.131706831845127 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.132494651551482 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.133282592203926 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.134070653821035 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.134858836421374 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.135647140023512 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.136435564646036 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.137224110307514 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.138012777026539 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.138801564821684 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.139590473711548 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.140379503714711 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.141168654849777 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.14195792713533 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.142747320589982 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1435368352323225 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.144326471080968 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1451162281545155 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1459061064715845 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.146696106050779 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1474862269107255 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.148276469070033 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.149066832547333 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.14985731736124 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.150647923530393 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.15143865107341 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.152229500008937 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.153020470355598 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.153811562132043 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.154602775356904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.155394110048836 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.156185566226476 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.156977143908485 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.157768843113505 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.158560663860205 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.15935260616723 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.160144670053256 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.160936855536937 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.161729162636949 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.162521591371952 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.163314141760632 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.164106813821654 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.164899607573707 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.165692523035463 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.166485560225618 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.167278719162847 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1680719998658535 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.16886540235332 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.169658926643953 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1704525727564405 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.171246340709496 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.172040230521814 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1728342422121125 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1736283757990975 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.174422631301477 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.175217008737977 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.176011508127307 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1768061294882015 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.177600872839372 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.178395738199559 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.179190725587482 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.179985835021886 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1807810665214955 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1815764201050625 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.182371895791317 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.183167493599016 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.183963213546896 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1847590556537195 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.18555501993823 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.186351106419193 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.187147315115359 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.187943646045501 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.188740099228373 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.189536674682755 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.190333372427407 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.191130192481113 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.19192713486264 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.192724199590778 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.193521386684298 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.194318696161999 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.195116128042657 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.195913682345074 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.196711359088033 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.197509158290343 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.1983070799707916 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.199105124148194 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.199903290841345 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.200701580069063 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.20149999185015 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.202298526203429 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.203097183147709 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.20389596270182 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.204694864884574 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.205493889714808 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.206293037211339 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.207092307393012 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.207891700278649 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.208691215887098 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.20949085423719 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.210290615347778 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.211090499237698 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.211890505925809 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.212690635430959 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2134908877719965 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.21429126296779 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.21509176103719 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.21589238199907 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.216693125872286 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.21749399267572 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.21829498242823 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2190960951487035 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.219897330856009 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.220698689569036 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.22150017130666 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.222301776087776 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.223103503931265 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.223905354856029 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.224707328880953 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.225509426024947 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2263116463069 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.227113989745727 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.227916456360326 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2287190461696165 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2295217591925 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.230324595447904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.231127554954735 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.231930637731928 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2327338437983935 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.233537173173072 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.234340625874883 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.235144201922768 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.235947901335655 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2367517241324935 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.237555670332212 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.23835973995377 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.239163933016101 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.239968249538169 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.240772689538915 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.241577253037306 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.242381940052293 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.243186750602846 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.243991684707922 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.244796742386498 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.245601923657535 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2464072285400185 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.247212657052913 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.24801820921521 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.248823885045881 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.249629684563922 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.250435607788312 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.251241654738052 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.252047825432131 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.252854119889541 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.253660538129293 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.25446708017038 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2552737460318175 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.256080535732605 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.256887449291764 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2576944867282975 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2585016480612365 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2593089333095895 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.260116342492391 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.260923875628656 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.261731532737424 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.262539313837719 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.263347218948585 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.26415524808905 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.264963401278165 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.265771678534964 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.266580079878505 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2673886053278265 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.268197254901992 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.269006028620045 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.269814926501057 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2706239485640785 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.271433094828184 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2722423653124295 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.273051760035896 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.273861279017648 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.274670922276771 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2754806898323325 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.276290581703427 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.277100597909127 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.277910738468533 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.278721003400723 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.279531392724802 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.280341906459857 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.281152544624998 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.281963307239316 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.282774194321927 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.28358520589193 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.284396341968445 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.285207602570577 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.286018987717455 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.286830497428186 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.2876421317219044 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.288453890617727 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.289265774134791 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.29007778229222 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.290889915109157 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.291702172604737 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.292514554798093 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.293327061708381 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.294139693354736 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.294952449756318 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.295765330932269 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.296578336901756 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.297391467683925 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.298204723297949 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.299018103762981 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.299831609098199 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.300645239322762 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.301458994455855 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.302272874516642 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.3030868795243125 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.303901009498038 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.304715264457014 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.305529644420418 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.306344149407451 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.307158779437296 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.30797353452916 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.308788414702232 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.309603419975726 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.310418550368835 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.3112338059007795 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.31204918659076 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.312864692458 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.313680323521708 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.314496079801113 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.3153119613154285 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.316127968083892 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.31694410012572 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.317760357460156 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.318576740106425 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.319393248083775 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.320209881411436 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.321026640108662 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.32184352419469 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.322660533688779 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.323477668610173 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.324294928978137 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.325112314811919 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.325929826130791 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.326747462954007 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.327565225300845 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.328383113190566 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.3292011266424515 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.3300192656757694 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.330837530309808 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.331655920563846 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.3324744364571615 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.333293078009054 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.334111845238803 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.334930738165716 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.335749756809077 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.336568901188197 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.3373881713223685 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.338207567230907 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.339027088933113 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.339846736448308 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.3406665097957955 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.341486408994904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.342306434064945 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.343126585025251 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.343946861895139 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.3447672646939495 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.345587793441004 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.346408448155648 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.347229228857211 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.348050135565044 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.348871168298482 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.349692327076881 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.350513611919584 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.3513350228459515 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.352156559875331 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.352978223027093 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.353800012320589 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.354621927775193 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.355443969410265 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.356266137245186 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.357088431299318 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.357910851592052 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.358733398142755 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.359556070970822 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.360378870095627 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.361201795536572 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.362024847313037 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.3628480254444275 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.363671329950131 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.36449476084956 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.365318318162107 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.366142001907189 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.3669658121042065 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.367789748772583 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.368613811931723 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.369438001601056 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.370262317799994 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.371086760547971 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.371911329864412 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.37273602576874 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.373560848280401 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.37438579741882 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.375210873203447 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.376036075653716 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.376861404789083 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.377686860628985 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.378512443192884 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.379338152500225 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.380163988570476 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.380989951423087 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.381816041077532 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.382642257553267 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.383468600869773 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.384295071046512 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.385121668102969 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.385948392058613 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.386775242932936 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.3876022207454115 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.3884293255155375 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.389256557262795 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.390083916006687 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# ...
# Warning: y = 9.755880854554619 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.75737857752319 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.75887653042222 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.760374713286994 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.761873126152832 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.763371769055025 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.764870642028907 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.76636974510978 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.76786907833299 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.769368641733847 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.770868435347708 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.772368459209897 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.773868713355782 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.775369197820693 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.776869912640011 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.77837085784908 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.779872033483288 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.781373439577992 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.782875076168592 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.784376943290452 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.785879040978983 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.787381369269564 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.788883928197615 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.790386717798524 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.791889738107725 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.793392989160624 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.794896470992638 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.796400183639214 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.797904127135766 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.799408301517756 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.800912706820608 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.802417343079794 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.80392221033075 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.805427308608959 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.806932637949865 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.808438198388965 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.809943989961715 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.811450012703617 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.812956266650144 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.814462751836807 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.815969468299087 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.817476416072513 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.81898359519257 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.820491005694798 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.821998647614697 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.823506520987817 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.825014625849667 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.826522962235808 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.828031530181761 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.829540329723098 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.831049360895353 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.832558623734103 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.834068118274898 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.835577844553326 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.837087802604943 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.838597992465353 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.84010841417012 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.841619067754861 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.84312995325515 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.844641070706613 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.84615242014484 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.847664001605464 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.849175815124084 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.850687860736349 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.852200138477867 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.853712648384297 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.855225390491258 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.856738364834419 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.858251571449413 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.859765010371918 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.861278681637579 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.862792585282083 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.864306721341087 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.865821089850291 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.86733569084537 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.868850524362005 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.870365590435913 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.871880889102778 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.873396420398324 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.874912184358248 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.876428181018285 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.877944410414141 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.879460872581568 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.880977567556277 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.88249449537403 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.884011656070554 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.885529049681619 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.887046676242964 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.888564535790369 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.890082628359584 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.891600953986403 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.893119512706583 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.89463830455593 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.896157329570213 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.897676587785249 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.899196079236816 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.900715803960743 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.902235761992824 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.90375595336889 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.90527637812475 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.90679703629625 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.908317927919205 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.909839053029472 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.91136041166288 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.912882003855294 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.914403829642556 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.915925889060544 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.917448182145105 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.918970708932132 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.920493469457485 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.922016463757064 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.92353969186674 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.925063153822428 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.926586849660007 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.928110779415402 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.929634943124505 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.931159340823253 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.932683972547547 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.934208838333335 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.935733938216531 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.937259272233092 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.938784840418943 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.940310642810056 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.941836679442373 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.943362950351844 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.944889455574458 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.946416195146165 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.947943169102965 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.949470377480816 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.950997820315731 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.95252549764368 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.954053409500688 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.955581555922732 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.957109936945848 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.95863855260603 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.960167402939323 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.961696487981728 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.963225807769302 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.964755362338062 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.96628515172407 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.967815175963358 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.969345435091997 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.97087592914603 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.972406658161544 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.973937622174587 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.975468821221257 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.977000255337616 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.978531924559775 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.980063828923802 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.98159596846582 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.983128343221914 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.984660953228211 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.986193798520807 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.987726879135847 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.989260195109432 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.990793746477719 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.992327533276825 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.99386155554291 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.995395813312108 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.996930306620587 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.998465035504495 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# ys: (0.001, 10.000), len(ys)=60000
# ws: (0.0001, 13000.000000), max_len(ws)=8000
# Total points in grid:  388130153

# %%
for grids in y_w_grid[::1000]:
    plt.scatter(grids[1], [grids[0]]*len(grids[1]))

plt.xscale('log') 
plt.yscale('log') 
plt.xlabel('$w$')
plt.ylabel('$y$')
plt.show()

# %%
y_w_grid[0][1]
# Out:
# array([1.00000000e-04, 1.00233840e-04, 1.00468227e-04, ...,
#        1.29394141e+04, 1.29696717e+04, 1.30000000e+04])
