# %% [markdown]
# # Lookup Table Generation for Point Lens Amplification factors
# ### For broader $y \in (10^{-3}, 10)$
# ### The settings are given here but whole lookup table is not generated. Instead, only part from (1e-3, 1e-2) is generated and then added to the existing data.

# %%
#!/home/anuj.mishra/anaconda3/envs/gwpy/bin/python

import numpy as np

import sys
import mpmath
from mpmath import hyp1f1
import math
import scipy
import pandas as pd

from copy import deepcopy

from itertools import product
from functools import partial
from tqdm import tqdm
import time
import matplotlib.pyplot as plt
import pickle

sys.path.append('../src/')
# loading Python version of the point lens class
import pnt_lens_class 
pnt_lens_py = pnt_lens_class.point_lens()

# loading Cython version of the point lens class
import cythonized_pnt_lens_class as pnt_lens_cy


import multiprocessing as mp
npool = 1  # int(sys.argv[1])


G = 6.67430*1e-11 
c = 299792458. 
M_sun = 1.989*1e30

# %% [markdown]
# ## 1. Bounds on w for lookup table

# %%
w_min, w_max = pnt_lens_cy.w_of_f(10, ml=1e-1), pnt_lens_cy.w_of_f(1024, ml=1e5)
('rough lower and upper limits of w:' , w_min, w_max )
# Out:
# ('rough lower and upper limits of w:',
#  0.00012382782869256283,
#  12679.969658118436)

# %% [markdown]
# ## 3. Grid Generation

# %%
## fitting a logspace for y grid points 

ys1 = np.logspace(-2, np.log10(5), 40000)
ys2 = np.logspace(-3, -2, 15000)
ys3 = np.logspace(np.log10(5), 1, 4500)
print(len(ys), len(ys2))

dys1 = [ ys1[i+1] - ys1[i] for i in range(len(ys1) -1 )]
dys2 = [ ys2[i+1] - ys2[i] for i in range(len(ys2) -1 )]
dys3 = [ ys3[i+1] - ys3[i] for i in range(len(ys3) -1 )]

# plt.scatter(ys[:-1], dys)
# plt.scatter(ys2[:-1], dys2)

fig, ax = plt.subplots(figsize=(10, 6))
plt.scatter(dys1, ys1[:-1])
plt.scatter(dys2, ys2[:-1])
plt.scatter(dys3, ys3[:-1])
plt.yscale('log')
plt.xscale('log')
plt.xlabel('$\Delta y$')
plt.ylabel('y')
plt.xticks(np.logspace(-7, -2, 5))
# plt.xlim(1e-8, 3e-2)
plt.show()
# Out:
# 40000 15000

# %%
## fitting a logspace for w grid points 

# ws_regs = [np.arange(1e-4, 1e-3, 5e-6),
# np.arange(1e-3, 1e-2, 5e-5),
# np.arange(1e-2, 1e-1, 5e-4),
# np.arange(1e-1, 1e-0, 5e-3),
# np.arange(1e-0, 1e1, 5e-2),
# np.arange(1e1, 1e2, 5e-1),
# np.arange(1e2, 1e3, 5e0),
# np.arange(1e3, 1.3e4+5e1, 5e1)]
# ws = np.concatenate(ws_regs)

ws_regs = [np.arange(1e-4, 1e-3, 1e-6),
np.arange(1e-3, 1e-2, 1e-5),
np.arange(1e-2, 1e-1, 1e-4),
np.arange(1e-1, 1e-0, 1e-3),
np.arange(1e-0, 1e1, 1e-2),
np.arange(1e1, 1e2, 1e-1),
np.arange(1e2, 1e3, 1e0),
np.arange(1e3, 1.3e4+1e1, 1e1)]
ws = np.concatenate(ws_regs)

ws2 = np.logspace(-4, np.log10(1.3e4), 6000)

print(len(ws), len(ws2))

dws = [ ws[i+1] - ws[i] for i in range(len(ws) -1 )]
dws2 = [ ws2[i+1] - ws2[i] for i in range(len(ws2) -1 )]

# plt.scatter(ys[:-1], dys)
# plt.scatter(ys2[:-1], dys2)
plt.scatter(dws, ws[:-1])
plt.scatter(dws2, ws2[:-1])
plt.yscale('log')
plt.xscale('log')
plt.xlabel('$\Delta w$')
plt.ylabel('w')
plt.xlim(1e-7, 1e2)
plt.show()
# Out:
# 7502 6000

# %%
ys = np.logspace(np.log10(5), np.log10(10.1), 4500)[1:]
ys[-1]
# Out:
# 10.100000000000001

# %%
### Grid Generation ###

ws_min, ws_max = 1e-4, 1.3e4

ys = np.logspace(np.log10(5), np.log10(10.1), 4500)[1:]
ws = np.logspace(np.log10(ws_min), np.log10(ws_max), 6000)

y_w_grid = []   #np.array([None]*len(input_prms))
for y in ys[:]:
    if y>0.01:
        wc = pnt_lens_cy.wc_geo_re1p0(y)
    else:
        wc = ws_max
    tmp_ws = ws[ws<=1.1*wc]
    y_w_grid.append([y, tmp_ws])
    
y_w_grid = np.array(y_w_grid, dtype=object)     
grid_num =  np.sum([len(y_w_grid[i][1]) for i in range(len(y_w_grid))])

print('ys: ({:.3f}, {:.3f}), len(ys)={}'.format(ys[0], ys[-1], len(ys)))
print('ws: ({:.4f}, {:2f}), max_len(ws)={}'.format(ws[0], ws[-1], len(ws)))
print('Total points in grid: ', grid_num)
# Out:
# Warning: y = 5.000781454160736 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.001563030455592 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.002344728903658 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0031265495240245 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.003908492335786 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.004690557358042 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0054727446098894 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.006255054110434 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.007037485878782 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.007820039934042 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.008602716295326 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.00938551498175 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.010168436012431 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.010951479406493 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.011734645183057 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.012517933361253 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.01330134396021 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.014084876999061 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.014868532496943 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.015652310472995 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.01643621094636 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.017220233936181 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.018004379461607 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0187886475417915 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.019573038195886 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.020357551443048 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.02114218730244 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.021926945793222 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.022711826934562 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0234968307456285 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.024281957245593 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.025067206453633 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.025852578388924 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.026638073070649 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.027423690517991 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.028209430750138 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.028995293786279 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.029781279645609 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.030567388347322 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.031353619910619 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.032139974354701 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.032926451698773 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.033713051962044 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.034499775163725 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.03528662132303 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.036073590459176 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0368606825913815 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.037647897738873 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.038435235920875 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.039222697156616 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.040010281465328 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.040797988866248 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.041585819378613 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.042373773021664 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.043161849814647 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.043950049776806 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.044738372927394 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.045526819285663 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.046315388870869 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0471040817022725 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.047892897799134 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0486818371807205 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0494708998663 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.050260085875142 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0510493952265225 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.051838827939719 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.05262838403401 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.053418063528681 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.054207866443016 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.054997792796307 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.055787842607844 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.056578015896925 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.057368312682845 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.058158732984909 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0589492768224185 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.059739944214683 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.060530735181012 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0613216497407185 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.062112687913121 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.062903849717537 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.063695135173291 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.064486544299706 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.065278077116112 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.06606973364184 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.066861513896226 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.067653417898607 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.068445445668323 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.069237597224719 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.07002987258714 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.070822271774937 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.071614794807463 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0724074417040725 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0732002124841244 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.073993107166983 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.07478612577201 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.075579268318575 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.076372534826049 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.077165925313805 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.077959439801223 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0787530783076775 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.079546840852556 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.080340727455242 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.081134738135127 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.081928872911601 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.082723131804061 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.083517514831904 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.08431202201453 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.085106653371347 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0859014089217585 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.086696288685177 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0874912926810145 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.088286420928688 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.089081673447618 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0898770502572255 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.090672551376936 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.09146817682618 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5
is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.890691761763302 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.892237586209259 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.893783652253402 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.895329959933498 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.896876509287305 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.898423300352599 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.899970333167154 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.901517607768756 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.903065124195193 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.904612882484258 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.906160882673756 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.907709124801492 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.909257608905278 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.910806335022933 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.912355303192285 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.913904513451156 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.915453965837392 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.917003660388826 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.918553597143315 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.920103776138705 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.921654197412865 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.923204861003653 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.924755766948946 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.926306915286618 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.927858306054556 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.929409939290647 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.930961815032788 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.93251393331888 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.934066294186831 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.935618897674553 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.937171743819967 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.938724832660998 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.940278164235572 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.941831738581637 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.943385555737123 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.94493961573999 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.946493918628184 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.948048464439674 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.949603253212418 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.951158284984398 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.952713559793585 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.954269077677967 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.955824838675532 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.957380842824278 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.958937090162209 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.96049358072733 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.962050314557658 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.963607291691211 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.965164512166018 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.966721976020104 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.968279683291517 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.96983763401829 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.971395828238485 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.972954265990145 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.974512947311343 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.976071872240137 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.977631040814611 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.979190453072835 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.9807501090529 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.982310008792895 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.98387015233092 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.985430539705076 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.986991170953473 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.988552046114226 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.990113165225457 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.991674528325294 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.993236135451868 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.994797986643322 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.996360081937793 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.997922421373444 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 9.999485004988419 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.001047832820893 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.002610904909025 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.004174221290999 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.005737782004985 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.007301587089183 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.008865636581778 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.010429930520964 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.011994468944952 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.013559251891959 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.015124279400192 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.016689551507874 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.018255068253234 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.019820829674515 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.021386835809952 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.022953086697786 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.024519582376278 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.02608632288368 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.027653308258264 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.029220538538292 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.030788013762049 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.032355733967806 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.033923699193867 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.03549190947851 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.037060364860052 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.038629065376787 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.040198011067028 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.041767201969096 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.043336638121321 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.04490631956203 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.046476246329549 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.048046418462231 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.049616835998428 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.051187498976487 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.052758407434766 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.05432956141164 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.05590096094547 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.057472606074647 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.059044496837544 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.060616633272561 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.062189015418085 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.063761643312528 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.06533451699429 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.06690763650179 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.06848100187345 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.070054613147686 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.071628470362938 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.07320257355765 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.07477692277026 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.076351518039212 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.077926359402976 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0795014469 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.081076780568766 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.082652360447737 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.084228186575404 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.085804258990242 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.087380577730753 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.08895714283543 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.090533954342781 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.092111012291316 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.093688316719545 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.095265867665995 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.0968436651692 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.09842170926769 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 10.100000000000001 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# ys: (5.001, 10.100), len(ys)=4499
# ws: (0.0001, 13000.000000), max_len(ws)=6000
# Total points in grid:  13302458

# %%
for grids in y_w_grid[::100]:
    plt.scatter(grids[1], [grids[0]]*len(grids[1]))

plt.xscale('log') 
plt.yscale('log') 
plt.xlabel('$w$')
plt.ylabel('$y$')
plt.show()

# %% [markdown]
# ## 4. Generating the lookup table

# %%
import pickle

outdir='../data/'
label = 'point_lens_Ff_lookup_table_Geo_relErr_1p0_ys_5_10'

if __name__=='__main__': 
    npool = 3
    pool = mp.Pool(processes=npool)
    t1=time.time()
    Ff_grid = dict()
    k=0
    for y_ws in tqdm(y_w_grid[:]):
        g_y = y_ws[0]
        g_ws = y_ws[1]
        Ff_eff_partial = partial(pnt_lens_py.point_Fw, y = g_y)
        tmp_res = np.array(list(pool.map(Ff_eff_partial, g_ws)))
        Ff_grid[str(k)] = dict(y=g_y, ws=g_ws, Ffs_real=np.real(tmp_res), Ffs_imag=np.imag(tmp_res))    
        k+=1
    t2 = time.time() 
    print('\nComputation Time (generation) = {:.2f} s'.format(t2-t1))

t1 = time.time()
with open(outdir + label + '.pkl', 'wb') as f:
    pickle.dump(Ff_grid, f)
t2 = time.time() 
print('Computation Time (exporting) = {:.2f} s'.format(t2-t1))  

with open(outdir + label + '.pkl', 'rb') as f:
    Ff_grid = pickle.load(f)

print('\nNumber of entries in lookup_table: ', len(Ff_grid))

# %%
outdir='../data/'
label = 'point_lens_Ff_lookup_table_Geo_relErr_1p0'

with open(outdir + label + '.pkl', 'rb') as f:
    Ff_grid = pickle.load(f)
Ff_grid_1 = Ff_grid
    
outdir='../data/'
label = 'point_lens_Ff_lookup_table_Geo_relErr_1p0_ys_1en3_1en2'

with open(outdir + label + '.pkl', 'rb') as f:
    Ff_grid = pickle.load(f)
Ff_grid_2 = Ff_grid

# %%
len(Ff_grid_1), len(Ff_grid_2)
# Out:
# (35000, 14)

# %%
Ff_grid_c = dict()

for i in range(len(Ff_grid_2)):
    Ff_grid_c[str(i)] = Ff_grid_2[str(i)]
    
for i in range(len(Ff_grid_1)):
    Ff_grid_c[str(i + len(Ff_grid_2))] = Ff_grid_1[str(i)]

# %%
len(Ff_grid_c)
# Out:
# 35014

# %%
Ff_grid_c['35013']
# Out:
# {'y': 5.000000000000001,
#  'ws': array([1.00000000e-04, 1.00311921e-04, 1.00624816e-04, ...,
#         1.17441312e+00, 1.17807637e+00, 1.18175104e+00]),
#  'Ffs_real': array([1.00007843, 1.00007868, 1.00007892, ..., 1.03330595, 1.03429526,
#         1.03516398]),
#  'Ffs_imag': array([-0.00030347, -0.00030426, -0.00030505, ..., -0.01726775,
#         -0.01526243, -0.01319419])}

# %%
import numpy as np
import pickle

outdir='../data/'
label = 'point_lens_Ff_lookup_table_Geo_relErr_1p0'

with open(outdir + label + '.pkl', 'rb') as f:
    Ff_grid = pickle.load(f)
Ff_grid_1 = Ff_grid
    
outdir='../data/'
label = 'point_lens_Ff_lookup_table_Geo_relErr_1p0_ys_1en3_1en2'

with open(outdir + label + '.pkl', 'rb') as f:
    Ff_grid = pickle.load(f)
Ff_grid_2 = Ff_grid


Ff_grid_c = dict()

for i in range(len(Ff_grid_2)):
    Ff_grid_c[str(i)] = Ff_grid_2[str(i)]
    
for i in range(len(Ff_grid_1)):
    Ff_grid_c[str(i + len(Ff_grid_2))] = Ff_grid_1[str(i)]

label = 'point_lens_Ff_lookup_table_Geo_relErr_1p0_Mlz_1e-1_1e5_ys_1e-3_5'    
with open(outdir + label + '.pkl', 'wb') as f:
    pickle.dump(Ff_grid_c, f)    
with open(outdir + label + '.pkl', 'rb') as f:
    Ff_grid = pickle.load(f)    
print('\nNumber of entries in lookup_table: ', len(Ff_grid))

# %%
#!/home/anuj.mishra/anaconda3/envs/gwpy/bin/python

import numpy as np

import sys
import mpmath
from mpmath import hyp1f1
import math
import scipy
import pandas as pd

from copy import deepcopy

from itertools import product
from functools import partial
from tqdm import tqdm
import time
import matplotlib.pyplot as plt
import pickle

sys.path.append('../src/')
# loading Python version of the point lens class
import pnt_lens_class 
pnt_lens_py = pnt_lens_class.point_lens()

# loading Cython version of the point lens class
import cythonized_pnt_lens_class as pnt_lens_cy


import multiprocessing as mp
npool = 1  # int(sys.argv[1])


G = 6.67430*1e-11 
c = 299792458. 
M_sun = 1.989*1e30


### Grid Generation ###

ws_min, ws_max = 1e-4, 1.3e4

ys = np.logspace(np.log10(5), np.log10(10.1), 4500)[1:]
ws = np.logspace(np.log10(ws_min), np.log10(ws_max), 6000)

y_w_grid = []   #np.array([None]*len(input_prms))
for y in ys[:]:
    if y>0.01:
        wc = pnt_lens_cy.wc_geo_re1p0(y)
    else:
        wc = ws_max
    tmp_ws = ws[ws<=1.1*wc]
    y_w_grid.append([y, tmp_ws])
    
y_w_grid = np.array(y_w_grid, dtype=object)     
grid_num =  np.sum([len(y_w_grid[i][1]) for i in range(len(y_w_grid))])

print('ys: ({:.3f}, {:.3f}), len(ys)={}'.format(ys[0], ys[-1], len(ys)))
print('ws: ({:.4f}, {:2f}), max_len(ws)={}'.format(ws[0], ws[-1], len(ws)))
print('Total points in grid: ', grid_num)


## lookup_table generation
import pickle

outdir='../data/'
label = 'point_lens_Ff_lookup_table_Geo_relErr_1p0_ys_5_10'

if __name__=='__main__': 
    npool = 3
    pool = mp.Pool(processes=npool)
    t1=time.time()
    Ff_grid = dict()
    k=0
    for y_ws in tqdm(y_w_grid[:10]):
        g_y = y_ws[0]
        g_ws = y_ws[1]
        Ff_eff_partial = partial(pnt_lens_py.point_Fw, y = g_y)
        tmp_res = np.array(list(pool.map(Ff_eff_partial, g_ws)))
        Ff_grid[str(k)] = dict(y=g_y, ws=g_ws, Ffs_real=np.real(tmp_res), Ffs_imag=np.imag(tmp_res))    
        k+=1
    t2 = time.time() 
    print('\nComputation Time (generation) = {:.2f} s'.format(t2-t1))

t1 = time.time()
with open(outdir + label + '.pkl', 'wb') as f:
    pickle.dump(Ff_grid, f)
t2 = time.time() 
print('Computation Time (exporting) = {:.2f} s'.format(t2-t1))  

with open(outdir + label + '.pkl', 'rb') as f:
    Ff_grid = pickle.load(f)

print('\nNumber of entries in lookup_table: ', len(Ff_grid))
# Out:
# Warning: y = 5.000781454160736 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.001563030455592 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.002344728903658 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0031265495240245 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.003908492335786 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.004690557358042 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0054727446098894 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.006255054110434 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.007037485878782 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.007820039934042 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.008602716295326 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.00938551498175 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.010168436012431 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.010951479406493 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.011734645183057 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.012517933361253 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.01330134396021 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.014084876999061 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.014868532496943 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.015652310472995 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.01643621094636 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.017220233936181 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.018004379461607 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0187886475417915 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.019573038195886 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.020357551443048 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.02114218730244 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.021926945793222 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.022711826934562 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0234968307456285 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.024281957245593 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.025067206453633 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.025852578388924 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.026638073070649 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.027423690517991 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.028209430750138 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.028995293786279 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.029781279645609 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.030567388347322 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.031353619910619 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.032139974354701 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.032926451698773 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.033713051962044 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.034499775163725 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.03528662132303 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.036073590459176 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0368606825913815 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.037647897738873 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.038435235920875 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.039222697156616 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.040010281465328 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.040797988866248 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.041585819378613 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.042373773021664 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.043161849814647 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.043950049776806 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.044738372927394 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.045526819285663 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.046315388870869 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0471040817022725 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.047892897799134 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0486818371807205 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0494708998663 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.050260085875142 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.0510493952265225 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.051838827939719 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.05262838403401 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.053418063528681 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.054207866443016 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.054997792796307 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5.055787842607844 is outside interpolation range (0.01, 5.00). Thus, Extrapolating!
# Warning: y = 5